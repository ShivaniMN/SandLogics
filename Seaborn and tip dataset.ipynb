# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#This graph is for one data column
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
#Distplot is used to compare two distplots
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
#there is a kind parameter inside joint plot which provides different distribution of points
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
#kde shows in which region of plot density of the tip is more

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#categorical plots
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#boxplot and violin plot are used to differentiate categorical data
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\categorical.py:2802: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='white')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='violin')
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap='coolwarm',linecolor='white',linewidths = 3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp)

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique();

# %%
g= sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
tips = sns.load_dataset('tips')

# %%
tip

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(plt.scatter,'total_bill','tip')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':50})

# %%
#linear model plot
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time',hue='day',aspect=0.6,size=8)
# Out:
# C:\Users\Shivani\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_context('poster')
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
pwd
# Out:
# 'C:\\Users\\Shivani'

# %%
import pandas as pd
df1 = pd.read_csv('E:\sandlogics\df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %% [markdown]
# df2 = pad.read_csv('E:\sandlogics\df2.csv',index_col=0)

# %%
df2 = pd.read_csv('E:\sandlogics\df2.csv',index_col=0)

# %%
df2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(lw=1,figsize=(12,3))
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A',y='B',c='C')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1['A'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#imputation technique

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#using subset of data for demonstration
df = tips.loc[:, ['total_bill','size','tip']]

# %%
df.loc[0:20,'size'] = np.nan
df.loc[210:240,'total_bill'] = np.nan

# %%
#mode imputation for size
mode_size = df['size'].mode()
df_modesize = df.fillna(value = {'size':mode_size[0]})

# %%
df_modesize
# Out:
#      total_bill  size   tip
# 0         16.99   2.0  1.01
# 1         10.34   2.0  1.66
# 2         21.01   2.0  3.50
# 3         23.68   2.0  3.31
# 4         24.59   2.0  3.61
# ..          ...   ...   ...
# 239         NaN   3.0  5.92
# 240         NaN   2.0  2.00
# 241       22.67   2.0  2.00
# 242       17.82   2.0  1.75
# 243       18.78   2.0  3.00
#
# [244 rows x 3 columns]

# %%
#Regression imputation on total_bills and check for correlation among variables
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
# #T_1de27_row0_col0,#T_1de27_row1_col1,#T_1de27_row2_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_1de27_row0_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_1de27_row0_col2{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_1de27_row1_col0,#T_1de27_row1_col2,#T_1de27_row2_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_1de27_row2_col0{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }</style><table id="T_1de27_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >size</th>        <th class="col_heading level0 col2" >tip</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
#creating a subset of data where there are no missing values in the tip and also total_bill
df_bill_tip = df.dropna(axis=0,subset=['total_bill','tip'])
df_bill_tip = df_bill_tip.loc[:,['total_bill','tip']]

# %%
df_bill_tip
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 208       24.27  2.03
# 209       12.76  2.23
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [213 rows x 2 columns]

# %%
#total bill missing entries
missing_bill = df['total_bill'].isnull()

#tips of observation with toral_bill missing
tip_missing = pd.DataFrame(df['tip'][missing_bill])

# %%
missing_bill
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240     True
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
tip_missing
# Out:
#       tip
# 210  2.00
# 211  5.16
# 212  9.00
# 213  2.50
# 214  6.50
# 215  1.10
# 216  3.00
# 217  1.50
# 218  1.44
# 219  3.09
# 220  2.20
# 221  3.48
# 222  1.92
# 223  3.00
# 224  1.58
# 225  2.50
# 226  2.00
# 227  3.00
# 228  2.72
# 229  2.88
# 230  2.00
# 231  3.00
# 232  3.39
# 233  1.47
# 234  3.00
# 235  1.25
# 236  1.00
# 237  1.17
# 238  4.67
# 239  5.92
# 240  2.00

# %%
df_l = df.fillna(method = 'ffill')

# %%
#(LOCF) last observation carried forward
df_l
# Out:
#      total_bill  size   tip
# 0         16.99   NaN  1.01
# 1         10.34   NaN  1.66
# 2         21.01   NaN  3.50
# 3         23.68   NaN  3.31
# 4         24.59   NaN  3.61
# ..          ...   ...   ...
# 239       12.76   3.0  5.92
# 240       12.76   2.0  2.00
# 241       22.67   2.0  2.00
# 242       17.82   2.0  1.75
# 243       18.78   2.0  3.00
#
# [244 rows x 3 columns]

# %%
#interpolation
interp = df.interpolate(method='linear',limit_direction='forward',axis=0)

# %%
interp
# Out:
#      total_bill  size   tip
# 0     16.990000   NaN  1.01
# 1     10.340000   NaN  1.66
# 2     21.010000   NaN  3.50
# 3     23.680000   NaN  3.31
# 4     24.590000   NaN  3.61
# ..          ...   ...   ...
# 239   22.050625   3.0  5.92
# 240   22.360312   2.0  2.00
# 241   22.670000   2.0  2.00
# 242   17.820000   2.0  1.75
# 243   18.780000   2.0  3.00
#
# [244 rows x 3 columns]
